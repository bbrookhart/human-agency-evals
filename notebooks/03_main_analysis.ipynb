# %% [markdown]
# # Main analysis
# No fabricated results. Execute from the repository root; inspect missingness before inference.

# %%
from pathlib import Path

from human_agency_evals.analysis.pipeline import analyze

run = Path("runs/full-001")
assert run.exists(), "Freeze the protocol before heldout execution"
analyze(run)
