# %% [markdown]
# # Dataset audit
# No fabricated results. Execute from the repository root; inspect missingness before inference.

# %%
from pathlib import Path

from human_agency_evals.datasets.loader import load
from human_agency_evals.datasets.validator import validate

validate(load([str(p) for p in Path("data").glob("*/scenarios.jsonl")]))
